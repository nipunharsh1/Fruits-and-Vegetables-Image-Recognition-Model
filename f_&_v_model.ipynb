# %% [markdown]
# <a href="https://colab.research.google.com/github/nipunharsh1/Fruits-and-Vegetables-Image-Recognition-Model/blob/main/f_%26_v_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
kritikseth_fruit_and_vegetable_image_recognition_path = kagglehub.dataset_download('kritikseth/fruit-and-vegetable-image-recognition')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kritikseth/fruit-and-vegetable-image-recognition?dataset_version_number=8...
# 100%|██████████| 1.98G/1.98G [01:07<00:00, 31.6MB/s]
# Extracting files...
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)
# Out:
# 2.19.0

# %%
train_dir = Path(kritikseth_fruit_and_vegetable_image_recognition_path) / 'train'
train_filepaths = list(train_dir.glob(r'**/*.jpg'))

# %%
test_dir = Path(kritikseth_fruit_and_vegetable_image_recognition_path) / 'test'
test_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
val_dir = Path(kritikseth_fruit_and_vegetable_image_recognition_path) / 'validation'
val_filepaths = list(val_dir.glob(r'**/*.jpg'))

# %%
def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures
    """

    labels = [str(filepath[i]).split("/")[-2] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)

    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 2780
#
# Number of different labels: 36
#
# Labels: ['soy beans' 'potato' 'paprika' 'apple' 'lemon' 'kiwi' 'onion' 'grapes'
#  'ginger' 'watermelon' 'pomegranate' 'carrot' 'peas' 'cabbage' 'mango'
#  'jalepeno' 'corn' 'eggplant' 'pear' 'cauliflower' 'tomato' 'lettuce'
#  'chilli pepper' 'spinach' 'orange' 'garlic' 'banana' 'pineapple'
#  'cucumber' 'beetroot' 'sweetcorn' 'turnip' 'capsicum' 'bell pepper'
#  'raddish' 'sweetpotato']

# %%
train_df.head(5)
# Out:
#                                             Filepath      Label
# 0  /root/.cache/kagglehub/datasets/kritikseth/fru...  soy beans
# 1  /root/.cache/kagglehub/datasets/kritikseth/fru...     potato
# 2  /root/.cache/kagglehub/datasets/kritikseth/fru...    paprika
# 3  /root/.cache/kagglehub/datasets/kritikseth/fru...      apple
# 4  /root/.cache/kagglehub/datasets/kritikseth/fru...      lemon

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

"""This code creates special tools called "data generators" for your images.

train_generator is for preparing images that will be used to train your model.
test_generator is for preparing images that will be used to test your model.
Both generators use a function (preprocess_input) that gets the images ready for a specific type of neural network (MobileNetV2) by adjusting their colors and values."""
# Out:
# 'This code creates special tools called "data generators" for your images.\n\ntrain_generator is for preparing images that will be used to train your model.\ntest_generator is for preparing images that will be used to test your model.\nBoth generators use a function (preprocess_input) that gets the images ready for a specific type of neural network (MobileNetV2) by adjusting their colors and values.'

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 2780 validated image filenames belonging to 36 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 334 validated image filenames belonging to 36 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 334 validated image filenames belonging to 36 classes.

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# > BELOW code builds and trains a neural network for classifying images of fruits and vegetables using TensorFlow and Keras. It starts by taking the input layer from a pre-trained model (likely MobileNet, given the filename), which allows you to leverage learned features from a large dataset. On top of the pre-trained model’s output, two fully connected (Dense) layers with 128 units each and ReLU activation are added. These layers help the model learn more complex patterns specific to your classification task.
#
# The final Dense layer has 36 units with a softmax activation, which means the model will output probabilities for 36 different classes—presumably one for each fruit or vegetable type. The model is then constructed by specifying its inputs and outputs.
#
# For training, the model is compiled with the Adam optimizer, categorical cross-entropy loss (suitable for multi-class classification), and accuracy as a metric to monitor. The fit function trains the model on your training images, validates on a separate set, and uses a batch size of 32 for 5 epochs. An EarlyStopping callback is included to halt training if the validation loss doesn’t improve for 2 consecutive epochs, and it restores the best weights found during training. This helps prevent overfitting and saves time by not training unnecessarily.

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(36, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.3616 - loss: 2.5447 - val_accuracy: 0.8683 - val_loss: 0.4392
# Epoch 2/5
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.8266 - loss: 0.5578 - val_accuracy: 0.9102 - val_loss: 0.2885
# Epoch 3/5
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.8901 - loss: 0.3359 - val_accuracy: 0.9461 - val_loss: 0.2239
# Epoch 4/5
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9254 - loss: 0.2331 - val_accuracy: 0.9491 - val_loss: 0.1934
# Epoch 5/5
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9530 - loss: 0.1490 - val_accuracy: 0.9521 - val_loss: 0.1867

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred1 = [labels[k] for k in pred]
pred1
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step
# ['bell pepper',
#  'sweetpotato',
#  'pineapple',
#  'carrot',
#  'jalepeno',
#  'bell pepper',
#  'carrot',
#  'ginger',
#  'capsicum',
#  'bell pepper',
#  'orange',
#  'kiwi',
#  'paprika',
#  'paprika',
#  'jalepeno',
#  'orange',
#  'cabbage',
#  'lettuce',
#  'kiwi',
#  'lemon',
#  'raddish',
#  'potato',
#  'lemon',
#  'banana',
#  'spinach',
#  'cauliflower',
#  'tomato',
#  'potato',
#  'banana',
#  'lettuce',
#  'watermelon',
#  'watermelon',
#  'pear',
#  'paprika',
#  'kiwi',
#  'carrot',
#  'jalepeno',
#  'apple',
#  'pear',
#  'cabbage',
#  'capsicum',
#  'chilli pepper',
#  'mango',
#  'corn',
#  'garlic',
#  'lettuce',
#  'cabbage',
#  'pineapple',
#  'onion',
#  'potato',
#  'potato',
#  'sweetcorn',
#  'onion',
#  'kiwi',
#  'garlic',
#  'mango',
#  'peas',
#  'sweetcorn',
#  'capsicum',
#  'chilli pepper',
#  'cucumber',
#  'sweetcorn',
#  'pineapple',
#  'beetroot',
#  'tomato',
#  'peas',
#  'ginger',
#  'eggplant',
#  'tomato',
#  'lettuce',
#  'kiwi',
#  'sweetpotato',
#  'pineapple',
#  'cabbage',
#  'turnip',
#  'chilli pepper',
#  'lettuce',
#  'paprika',
#  'spinach',
#  'ginger',
#  'eggplant',
#  'garlic',
#  'sweetcorn',
#  'chilli pepper',
#  'cauliflower',
#  'lemon',
#  'sweetcorn',
#  'cucumber',
#  'pomegranate',
#  'capsicum',
#  'potato',
#  'garlic',
#  'grapes',
#  'beetroot',
#  'watermelon',
#  'kiwi',
#  'ginger',
#  'raddish',
#  'potato',
#  'cucumber',
#  'kiwi',
#  'eggplant',
#  'grapes',
#  'mango',
#  'banana',
#  'pear',
#  'grapes',
#  'ginger',
#  'onion',
#  'tomato',
#  'cauliflower',
#  'spinach',
#  'soy beans',
#  'banana',
#  'pomegranate',
#  'turnip',
#  'carrot',
#  'orange',
#  'sweetcorn',
#  'sweetcorn',
#  'sweetcorn',
#  'lemon',
#  'bell pepper',
#  'cabbage',
#  'lemon',
#  'beetroot',
#  'lettuce',
#  'pear',
#  'jalepeno',
#  'pineapple',
#  'watermelon',
#  'turnip',
#  'peas',
#  'lemon',
#  'raddish',
#  'sweetcorn',
#  'bell pepper',
#  'turnip',
#  'pineapple',
#  'cucumber',
#  'raddish',
#  'cucumber',
#  'soy beans',
#  'apple',
#  'cucumber',
#  'sweetpotato',
#  'capsicum',
#  'cauliflower',
#  'pear',
#  'banana',
#  'orange',
#  'pineapple',
#  'raddish',
#  'beetroot',
#  'chilli pepper',
#  'cauliflower',
#  'jalepeno',
#  'mango',
#  'jalepeno',
#  'tomato',
#  'capsicum',
#  'grapes',
#  'cucumber',
#  'lettuce',
#  'soy beans',
#  'apple',
#  'carrot',
#  'mango',
#  'sweetcorn',
#  'tomato',
#  'watermelon',
#  'pomegranate',
#  'sweetcorn',
#  'bell pepper',
#  'paprika',
#  'grapes',
#  'sweetpotato',
#  'pineapple',
#  'grapes',
#  'spinach',
#  'orange',
#  'sweetcorn',
#  'kiwi',
#  'bell pepper',
#  'sweetpotato',
#  'pomegranate',
#  'pomegranate',
#  'lettuce',
#  'raddish',
#  'peas',
#  'pomegranate',
#  'mango',
#  'cauliflower',
#  'apple',
#  'cabbage',
#  'raddish',
#  'apple',
#  'sweetpotato',
#  'bell pepper',
#  'chilli pepper',
#  'soy beans',
#  'lemon',
#  'garlic',
#  'pomegranate',
#  'jalepeno',
#  'sweetpotato',
#  'peas',
#  'mango',
#  'cucumber',
#  'orange',
#  'sweetcorn',
#  'mango',
#  'spinach',
#  'tomato',
#  'capsicum',
#  'potato',
#  'eggplant',
#  'cabbage',
#  'onion',
#  'capsicum',
#  'ginger',
#  'ginger',
#  'turnip',
#  'onion',
#  'pear',
#  'soy beans',
#  'sweetcorn',
#  'pomegranate',
#  'beetroot',
#  'onion',
#  'mango',
#  'watermelon',
#  'watermelon',
#  'pineapple',
#  'watermelon',
#  'apple',
#  'paprika',
#  'garlic',
#  'spinach',
#  'pomegranate',
#  'carrot',
#  'beetroot',
#  'beetroot',
#  'soy beans',
#  'ginger',
#  'pear',
#  'watermelon',
#  'beetroot',
#  'soy beans',
#  'garlic',
#  'tomato',
#  'corn',
#  'apple',
#  'onion',
#  'capsicum',
#  'watermelon',
#  'pineapple',
#  'peas',
#  'chilli pepper',
#  'eggplant',
#  'ginger',
#  'cauliflower',
#  'soy beans',
#  'cauliflower',
#  'mango',
#  'sweetpotato',
#  'sweetcorn',
#  'tomato',
#  'eggplant',
#  'eggplant',
#  'cabbage',
#  'soy beans',
#  'chilli pepper',
#  'spinach',
#  'pomegranate',
#  'sweetcorn',
#  'garlic',
#  'chilli pepper',
#  'cabbage',
#  'raddish',
#  'jalepeno',
#  'turnip',
#  'eggplant',
#  'potato',
#  'onion',
#  'cauliflower',
#  'turnip',
#  'beetroot',
#  'raddish',
#  'garlic',
#  'spinach',
#  'bell pepper',
#  'kiwi',
#  'pear',
#  'pear',
#  'kiwi',
#  'sweetpotato',
#  'banana',
#  'cabbage',
#  'cucumber',
#  'turnip',
#  'carrot',
#  'eggplant',
#  'jalepeno',
#  'grapes',
#  'capsicum',
#  'chilli pepper',
#  'peas',
#  'lemon',
#  'sweetcorn',
#  'ginger',
#  'pear',
#  'potato',
#  'garlic',
#  'tomato',
#  'soy beans',
#  'banana',
#  'beetroot',
#  'cucumber',
#  'peas',
#  'corn',
#  'eggplant',
#  'onion',
#  'mango',
#  'grapes',
#  'orange',
#  'capsicum',
#  'turnip',
#  'spinach',
#  'spinach',
#  'peas',
#  'spinach',
#  'turnip',
#  'sweetpotato']

# %%
def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict(img)
    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels[y]
    return res

# %%
from pathlib import Path

img_path = Path(kritikseth_fruit_and_vegetable_image_recognition_path) / 'validation' / 'cabbage' / 'Image_7.jpg'
img = output(str(img_path))
img

# %%
model.save('FV.h5')
